# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
vehical_data=pd.read_csv(r'"D:\taha\HSRW\Submission_SciCom_(31709 + 31661)\table\auto-mpg.csv"auto-mpg.csv')
vehical_data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
vehical_data.info()
vehical_data.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB
# (398, 9)

# %%
vehical_data.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
#Cyclinder
vehical_data.cylinders.value_counts()
vehical_data.cylinders.value_counts().sum()
#barplot
sns.countplot(vehical_data.cylinders)
plt.ylabel('No of cars')
plt.title('cylinder')
plt.show()
# Out:
# C:\Users\prath\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
vehical_data['acceleration'].plot.box(color='red',vert=False, patch_artist=True)
plt.xlabel('Acceleration')
plt.title('Boxplot-acceleration')
plt.show()

# %%
sns.heatmap(vehical_data.corr(),annot=True)
vehical_data.corr()['acceleration']
# Out:
# mpg             0.420289
# cylinders      -0.505419
# displacement   -0.543684
# weight         -0.417457
# acceleration    1.000000
# model year      0.288137
# origin          0.205873
# Name: acceleration, dtype: float64

# %%
plt.hist(vehical_data.displacement)
plt.xlabel('Displacement')
plt.ylabel('No of Cars')
plt.title('Histogram- Displacement')
plt.show()

# %%
sns.scatterplot(x='displacement',y='cylinders',data=vehical_data,hue='cylinders')
plt.title('DISPLACEMENT WITH RESPECT TO CYLINDERS')
plt.show()

# %%
plt.hist(vehical_data.acceleration)
plt.xlabel('Acceleration')
plt.xticks (rotation=90)
plt.ylabel('No of Cars')
plt.title('Histogram- Acceleration')
plt.show()
